# %%
import pandas as pd

# %%
from scipy.io import arff

# %%
data = arff.loadarff('4year.arff')
df = pd.DataFrame(data[0])

# %%
df['bankruptcy'] = (df['class']==b'1')

# %%
df.head()
# Out:
#       Attr1    Attr2    Attr3   Attr4    Attr5     Attr6     Attr7    Attr8  \
# 0  0.159290  0.46240  0.07773  1.1683  -44.853  0.467020  0.189480  0.82895
# 1 -0.127430  0.46243  0.26917  1.7517    7.597  0.000925 -0.127430  1.16250
# 2  0.070488  0.23570  0.52781  3.2393  125.680  0.163670  0.086895  2.87180
# 3  0.136760  0.40538  0.31543  1.8705   19.115  0.504970  0.136760  1.45390
# 4 -0.110080  0.69793  0.18878  1.2713  -15.344  0.000000 -0.110080  0.43282
#
#     Attr9   Attr10     ...       Attr57   Attr58    Attr59   Attr60  Attr61  \
# 0  1.1223  0.38330     ...      0.41557  0.89101  0.001422   7.7928  4.9914
# 1  1.2944  0.53757     ...     -0.23704  1.06250  0.150410   5.4327  3.4629
# 2  1.0574  0.67689     ...      0.10413  0.94571  0.000000   7.1070  3.3808
# 3  1.1144  0.58938     ...      0.23203  0.89737  0.073024   6.1384  4.2241
# 4  1.7350  0.30207     ...     -0.36440  0.57153  0.000000  18.8010  2.7925
#
#     Attr62  Attr63   Attr64  class  bankruptcy
# ...

# %%
dataframe_1=pd.DataFrame(df,columns=['Attr1','Attr2','Attr7','Attr10','bankruptcy'])

# %%
dataframe_1.head()
# Out:
#       Attr1    Attr2     Attr7   Attr10  bankruptcy
# 0  0.159290  0.46240  0.189480  0.38330       False
# 1 -0.127430  0.46243 -0.127430  0.53757       False
# 2  0.070488  0.23570  0.086895  0.67689       False
# 3  0.136760  0.40538  0.136760  0.58938       False
# 4 -0.110080  0.69793 -0.110080  0.30207       False

# %%
dataframe_1 = dataframe_1.rename(columns={'Attr1':'X1', 'Attr2':'X2','Attr7':'X7','Attr10':'X10'})

# %% [markdown]
# ## Q1 Create a new dataframe with only 4 feataures (and and Bankruptcy). Properly rename the columns to X1, X2, X7, and X10

# %%
dataframe_1.head()
# Out:
#          X1       X2        X7      X10  bankruptcy
# 0  0.159290  0.46240  0.189480  0.38330       False
# 1 -0.127430  0.46243 -0.127430  0.53757       False
# 2  0.070488  0.23570  0.086895  0.67689       False
# 3  0.136760  0.40538  0.136760  0.58938       False
# 4 -0.110080  0.69793 -0.110080  0.30207       False

# %% [markdown]
# ## Q2 Fill-in the missing values na with the mean.

# %%
dataframe_1.fillna(dataframe_1.mean())
# Out:
#             X1        X2        X7       X10  bankruptcy
# 0     0.159290  0.462400  0.189480  0.383300       False
# 1    -0.127430  0.462430 -0.127430  0.537570       False
# 2     0.070488  0.235700  0.086895  0.676890       False
# 3     0.136760  0.405380  0.136760  0.589380       False
# 4    -0.110080  0.697930 -0.110080  0.302070       False
# 5     0.021539  0.584250  0.029628  0.415750       False
# 6     0.227430  0.522660  0.283000  0.477340       False
# 7     0.038662  0.594980  0.038662  0.405020       False
# 8     0.131030  0.472020  0.163780  0.527980       False
# 9     0.176980  0.193590  0.212810  0.806410       False
# 10    0.117670  0.373320  0.145710  0.626680       False
# 11    0.032153  0.902120  0.032153  0.097879       False
# 12   -0.075580  0.936210 -0.075580  0.013214       False
# 13    0.211890  0.233070  0.264610  0.719900       False
# 14    0.046169  0.247930  0.048998  0.743240       False
# ...

# %% [markdown]
# ## Q3 the mean and std of the 4 features among all companies

# %%
dataframe_1.mean()
# Out:
# X1            0.043019
# X2            0.596404
# X7            0.059446
# X10           0.389040
# bankruptcy    0.052594
# dtype: float64

# %%
dataframe_1.std()
# Out:
# X1            0.359321
# X2            4.587122
# X7            0.533344
# X10           4.590299
# bankruptcy    0.223233
# dtype: float64

# %% [markdown]
# ## Q3 the mean and std of the 4 features among bankruptcy companies

# %%
dataframe_bankcruptcy=dataframe_1.loc[dataframe_1['bankruptcy']==True]

# %%
dataframe_bankcruptcy.mean()
# Out:
# X1           -0.068873
# X2            0.878355
# X7           -0.061538
# X10           0.103367
# bankruptcy    1.000000
# dtype: float64

# %%
dataframe_bankcruptcy.std()
# Out:
# X1            0.568076
# X2            1.945596
# X7            0.568432
# X10           1.946747
# bankruptcy    0.000000
# dtype: float64

# %% [markdown]
# ## Q3 the mean and std of the 4 features among operating companies

# %%
dataframe_operating=dataframe_1.loc[dataframe_1['bankruptcy']==False]

# %%
dataframe_operating.mean()
# Out:
# X1            0.049231
# X2            0.580750
# X7            0.066163
# X10           0.404901
# bankruptcy    0.000000
# dtype: float64

# %%
dataframe_operating.std()
# Out:
# X1            0.343020
# X2            4.689947
# X7            0.530553
# X10           4.693187
# bankruptcy    0.000000
# dtype: float64

# %% [markdown]
# ## Q4 How many companies satisfy the condition, X1 < mean(X1) - stdev(X1) AND X10 < mean(X10) - std(X10)?

# %%
condition1 = dataframe_1['X1'] < dataframe_1['X1'].mean() - dataframe_1['X1'].std() 
condition2 = dataframe_1['X10'] < dataframe_1['X10'].mean()- dataframe_1['X10'].std()

# %%
subset = dataframe_1.loc[condition1&condition2,:]

# %%
num=subset.bankruptcy.count()
num
# Out:
# 15

# %% [markdown]
# ## Q5 What is the ratio of the bankrupted companies among the sub-groups above?

# %%
bankruptcy_ratio=(subset.loc[subset['bankruptcy']]).shape[0]/num
bankruptcy_ratio
# Out:
# 0.2
